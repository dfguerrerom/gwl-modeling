# %%
import pandas as pd
import geopandas as gpd

# %%
df = pd.read_pickle('~/Indonesia_sm/cleaned_station_data/cleaned_field_stations.pickle')

# %%
gdf = gpd.read_file('~/Indonesia_sm/cleaned_station_data/final_training_data.gpkg')

# %%
gdf
# Out:
#                           index        station        location  \
# 0     2019-10-16T00:00:00+00:00  BRG_150611_02  Bram Itam Raya
# 1     2019-03-14T00:00:00+00:00  BRG_150611_02  Bram Itam Raya
# 2     2020-01-08T00:00:00+00:00  BRG_150611_02  Bram Itam Raya
# 3     2020-02-12T00:00:00+00:00  BRG_150611_02  Bram Itam Raya
# 4     2018-12-31T00:00:00+00:00  BRG_150611_02  Bram Itam Raya
# ...                         ...            ...             ...
# 1393  2019-02-05T00:00:00+00:00          brg14       KATUNJUNG
# 1394  2019-01-31T00:00:00+00:00          brg14       KATUNJUNG
# 1395  2019-01-24T00:00:00+00:00          brg14       KATUNJUNG
# 1396  2019-01-12T00:00:00+00:00          brg14       KATUNJUNG
# 1397  2019-01-19T00:00:00+00:00          brg14       KATUNJUNG
#
#                province         lon       lat  GWL_max  GWL_min  GWL_rata  \
# 0                 JAMBI  103.354661 -0.921704   -1.079   -1.094    -1.085
# ...
