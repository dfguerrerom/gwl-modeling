# %%
import pandas as pd
from gee_scripts.model import

# %%
df = pd.read_csv("data/9_clean_training_data/clean_training_data.csv")
df
# Out:
#         source               id        date  gwl_cm       lat         lon  \
# 0          wal  02_AHL_SBG-B076  2021-06-01  -41.00  3.937760  117.007750
# 1          wal  02_AHL_SBG-B076  2021-08-24  -38.00  3.937760  117.007750
# 2          wal  02_AHL_SBG-B076  2022-04-09  -22.00  3.937760  117.007750
# 3          wal  02_AHL_SBG-B076  2023-02-15  -31.00  3.937760  117.007750
# 4          wal  02_AHL_SBG-B101  2022-04-09  -34.00  3.931860  117.010120
# ...        ...              ...         ...     ...       ...         ...
# 31093  old_brg         kalteng1  2020-03-31   -2.71 -2.319728  114.058131
# 31094  old_brg         kalteng1  2020-04-12   -1.14 -2.319728  114.058131
# 31095  old_brg           kecil1  2019-03-01  -29.54 -2.856089  113.805611
# 31096  old_brg           kecil1  2019-06-29  -29.22 -2.856089  113.805611
# 31097  old_brg           kecil1  2019-10-27  -30.23 -2.856089  113.805611
#
#              LIA         VH         VV  VVVH_ratio  ...  B3  B4   B5  B7  \
# ...
